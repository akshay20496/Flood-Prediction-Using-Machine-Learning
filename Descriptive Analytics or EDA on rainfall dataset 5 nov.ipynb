# %% [markdown]
# # Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
# %matplotlib inline

# %% [markdown]
# # Load the rainfall dataset

# %%
df = pd.read_csv('rainfall.csv')
#shape of the dataset
print(df.shape)
# Out:
# (4116, 19)

# %% [markdown]
# 4116 rows and 19 columns

# %%
#display 5 lines of the dataset
df.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
#Explore the columns and their datatypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %% [markdown]
# # Summary of the dataset

# %%
df.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR  \
# count  4116.000000  4112.000000  4113.000000  4110.000000  4112.000000
# mean   1958.218659    18.957320    21.805325    27.359197    43.127432
# std      33.140898    33.585371    35.909488    46.959424    67.831168
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1958.000000     6.000000     6.700000     7.800000    15.700000
# 75%    1987.000000    22.200000    26.800000    31.300000    49.950000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP  \
# count  4113.000000  4111.000000  4109.000000  4112.000000  4110.000000
# mean     85.745417   230.234444   347.214334   290.263497   197.361922
# std     123.234904   234.710758   269.539667   188.770477   135.408345
# ...

# %%
# check the columns

# %%
df.columns
# Out:
# Index(['SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL',
#        'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb', 'Mar-May',
#        'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %% [markdown]
# # How many records each sub-division has?

# %%
df['SUBDIVISION'].value_counts()
# Out:
# VIDARBHA                              115
# ORISSA                                115
# EAST UTTAR PRADESH                    115
# RAYALSEEMA                            115
# MADHYA MAHARASHTRA                    115
# GUJARAT REGION                        115
# NORTH INTERIOR KARNATAKA              115
# UTTARAKHAND                           115
# KERALA                                115
# KONKAN & GOA                          115
# MATATHWADA                            115
# GANGETIC WEST BENGAL                  115
# EAST RAJASTHAN                        115
# JHARKHAND                             115
# SUB HIMALAYAN WEST BENGAL & SIKKIM    115
# WEST UTTAR PRADESH                    115
# ASSAM & MEGHALAYA                     115
# SOUTH INTERIOR KARNATAKA              115
# COASTAL KARNATAKA                     115
# HIMACHAL PRADESH                      115
# PUNJAB                                115
# TELANGANA                             115
# ...

# %% [markdown]
# # Select SUBDIVISION 'Madhya Maharashtra'

# %%
df_up = df[df.SUBDIVISION == 'MADHYA MAHARASHTRA']
df_up
# Out:
#              SUBDIVISION  YEAR   JAN  FEB   MAR   APR   MAY    JUN    JUL  \
# 2622  MADHYA MAHARASHTRA  1901  18.8  0.6   7.7  36.6  30.4  107.7  215.9
# 2623  MADHYA MAHARASHTRA  1902   7.8  0.0   0.1   5.0   9.8  102.6  210.9
# 2624  MADHYA MAHARASHTRA  1903   7.6  0.0   0.0   3.2  77.2   86.3  281.8
# 2625  MADHYA MAHARASHTRA  1904   0.4  4.7   1.7   3.0  18.7  114.6  126.5
# 2626  MADHYA MAHARASHTRA  1905   0.0  1.2   0.0   2.3  23.6   65.0  252.8
# ...                  ...   ...   ...  ...   ...   ...   ...    ...    ...
# 2732  MADHYA MAHARASHTRA  2011   0.0  0.3   0.3   5.0   2.9  133.3  261.4
# 2733  MADHYA MAHARASHTRA  2012   0.0  0.0   0.0   3.0   1.4   67.9  203.0
# 2734  MADHYA MAHARASHTRA  2013   0.1  5.3   0.8   5.7   6.0  212.4  311.8
# 2735  MADHYA MAHARASHTRA  2014   3.1  6.2  24.4   7.5  29.8   44.0  277.9
# 2736  MADHYA MAHARASHTRA  2015   1.4  0.8  41.2   9.6  24.4  177.0  111.7
#
#         AUG    SEP   OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# ...

# %% [markdown]
# # Plot the graph showing the trend of rainfall in Madhya Maharashtra

# %%
df_up.plot(figsize = (8,8), legend=True)

# %% [markdown]
# # Which are the 10 SUBDIVISION with less rainfall in the 2005?

# %%
df2000 = df.groupby('YEAR').get_group(2005)
less_rainfall10 = df2000[['SUBDIVISION','YEAR','ANNUAL']].sort_values('ANNUAL')
less_rainfall10.head(15)
# Out:
#                      SUBDIVISION  YEAR  ANNUAL
# 1921              WEST RAJASTHAN  2005   260.8
# 1461  HARYANA DELHI & CHANDIGARH  2005   519.5
# 1576                      PUNJAB  2005   552.0
# 2036              EAST RAJASTHAN  2005   567.9
# 2496          SAURASHTRA & KUTCH  2005   631.6
# 1231          WEST UTTAR PRADESH  2005   725.7
# 2151         WEST MADHYA PRADESH  2005   752.2
# 1116          EAST UTTAR PRADESH  2005   770.3
# 3761    NORTH INTERIOR KARNATAKA  2005   807.5
# 1001                       BIHAR  2005   907.8
# 2841                  MATATHWADA  2005   940.5
# 886                    JHARKHAND  2005   960.4
# 3416                  RAYALSEEMA  2005  1066.4
# 3301                   TELANGANA  2005  1163.1
# 2956                    VIDARBHA  2005  1214.6

# %%
less_rainfall10.plot(x= 'SUBDIVISION', y='ANNUAL', figsize=(8,8))

# %% [markdown]
# # Which are the 10 SUBDIVISION with high rainfall in the 2005?

# %%
df2000 = df.groupby('YEAR').get_group(2005)
high_rainfall10 = df2000[['SUBDIVISION','YEAR','ANNUAL','AUG']].sort_values('AUG')
high_rainfall10.tail(15)
# Out:
#                              SUBDIVISION  YEAR  ANNUAL    AUG
# 3876            SOUTH INTERIOR KARNATAKA  2005  1319.3  233.2
# 1346                         UTTARAKHAND  2005  1348.2  249.2
# 2956                            VIDARBHA  2005  1214.6  249.2
# 2726                  MADHYA MAHARASHTRA  2005  1221.3  256.1
# 2266                 EAST MADHYA PRADESH  2005  1366.4  256.6
# 3071                        CHHATTISGARH  2005  1287.2  267.7
# 3991                              KERALA  2005  3031.1  291.0
# 1001                               BIHAR  2005   907.8  309.1
# 99             ANDAMAN & NICOBAR ISLANDS  2005  2954.7  311.1
# 426               NAGA MANI MIZO TRIPURA  2005  1836.7  334.8
# 196                    ARUNACHAL PRADESH  2005  2335.5  400.0
# 311                    ASSAM & MEGHALAYA  2005  2468.3  501.9
# 541   SUB HIMALAYAN WEST BENGAL & SIKKIM  2005  2807.7  564.5
# 3646                   COASTAL KARNATAKA  2005  3470.9  692.0
# ...

# %%
high_rainfall10.plot(x= 'SUBDIVISION', y='AUG', figsize=(8,8))
